# %%
import sys
from google.colab import drive
drive.mount('/content/gdrive')
sys.path.append("/content/gdrive/My Drive/Mastersthesis/TBH")
from train import tbh_train
import tensorflow as tf
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
sys.path.append("/content/gdrive/My Drive/Mastersthesis/TBH")
root = "/content/gdrive/My Drive/Mastersthesis/TBH/util/convert_examples"

import numpy as np
bas = np.array(plt.imread(root+"/examples_baseline.jpg"))
new = np.array(plt.imread(root+"/examples_new.jpg"))

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.imshow(new)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plt.imshow(bas)

# %%
merged = np.zeros((32*20+5*10,64+32*10+5,3),dtype=int)

# %%
for i in range(10):
  merged[69*i:69*i+32,64:,:] = new[i*32:i*32+32,32:,:]
  merged[69*i+34:69*i+66,64:,:] = bas[i*32:i*32+32,32:,:]
  for k in range(64):
    for l in range(64):
      merged[i*69+k+2,l,:] = new[i*32+int(k/2),int(l/2),:]

# %%
plt.imshow(merged)

# %%
plt.imsave(root + "/examples_merged.jpg", merged.astype("uint8"))
